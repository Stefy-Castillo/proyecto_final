# %% [markdown]
# # Librerias

# %%
import pickle
import pandas as pd
import numpy as np
import warnings
import re
from unidecode import unidecode
from tqdm import tqdm

import requests
from bs4 import BeautifulSoup

warnings.filterwarnings('ignore')

# %% [markdown]
# # Mis funciones

# %%
import import_ipynb
from mis_funciones import *
# Out:
# importing Jupyter notebook from mis_funciones.ipynb

# %% [markdown]
# # Extracción urls Beer Station

# %%
urls_shows = []
locales_shows = []
nombre_shows = []
n_opiniones = []  # Lista para almacenar el número de opiniones

for i in range(1, 10):
    url = f'https://www.atrapalo.com/entradas/madrid/teatro-y-danza/monologos/p-{i}/'
    
    res1 = requests.get(url)
    sopa = BeautifulSoup(res1.content, 'html.parser')

    urls = sopa.find_all("a", {"class": "product-name"})
    for url_evento in urls:
        urls_shows.append(url_evento['href'])
        nombre_local = url_evento.find_next("a", {"class": "locality GATrackEvent_ubicacion hide-for-small-only"}).text
        locales_shows.append(nombre_local)

        nombre_show = url_evento.text.strip()
        nombre_shows.append(nombre_show)
        
        # Obtener el número de opiniones
        url_completa = 'https://www.atrapalo.com/' + url_evento['href']
        response = requests.get(url_completa)
        soup = BeautifulSoup(response.content, 'html.parser')

        # Buscar el texto que contiene el número de opiniones
        texto_opiniones = soup.get_text()

        # Buscar un patrón de texto que incluya el número de opiniones
        match = re.search(r'(\d+)\s+opiniones', texto_opiniones)

        if match:
            # Extraer el número de opiniones
            num_opiniones = int(match.group(1))
            n_opiniones.append(num_opiniones)
        else:
            # Si no se encuentra el texto, agregar un valor predeterminado (por ejemplo, -1)
            n_opiniones.append(-1)



# Crear el DataFrame
df = pd.DataFrame({'url': urls_shows, 'local': locales_shows, 'nombre_show': nombre_shows, 'n_opiniones': n_opiniones})

df
# Out:
#                                                    url  \
# 0    /entradas/la-hora-y-media-de-el-club-de-la-com...
# 1    /entradas/los-monologos-de-el-golfo-comedy-clu...
# 2    /entradas/tinder-sorpresa-andreu-casanova-en-m...
# 3    /entradas/tamagochi-un-monologo-millennial-de-...
# 4    /entradas/cupido-debe-morir-el-monologo-del-de...
# ..                                                 ...
# 319  /entradas/coolturetas-comedy-3-comicos-jam-mus...
# 320  /entradas/chic-comedy-show-especial-halloween_...
# 321                       /entradas/desastre_e4901558/
# 322                   /entradas/la-pozzoleta_e4858217/
# 323  /entradas/la-hora-y-media-de-el-club-de-la-com...
#
#                                   local  \
# 0              Teatro Príncipe Gran Vía
# 1                  El Golfo Comedy Club
# 2    Cine Palacio de la Prensa - Sala 1
# 3                      Teatro Soho Club
# 4    Cine Palacio de la Prensa - Sala 3
# ..                                  ...
# 319                       Espacio Iroko
# 320                       Estupenda Bar
# 321         Teatro Quique San Francisco
# 322    Viva la vida (Alcalá de Henares)
# 323                     Teatro Zorrilla
#
#                                            nombre_show  n_opiniones
# 0      La Hora y Media de El Club de la Comedia Madrid         4163
# 1      Los Monólogos de El Golfo Comedy Club en Madrid         1739
# 2         Tinder Sorpresa - Andreu Casanova, en Madrid         4322
# 3    Tamagochi: un monólogo Millennial de Silvia De...           86
# 4    Cupido debe morir: el monólogo del desamor de ...          251
# ..                                                 ...          ...
# 319  Coolturetas Comedy 3 Cómicos + Jam música en D...          107
# 320              Chic Comedy Show - Especial Halloween            2
# 321                                           Desastre           -1
# 322                                       La Pozzoleta          114
# 323  La Hora y Media de El Club de la Comedia Valla...           -1
#
# [324 rows x 4 columns]

# %%
# Filtrar el DataFrame
df_beer = df[df['local'] == 'Beer Station - Sala 1']

# Mostrar el nuevo DataFrame
df_beer
# Out:
#                                                    url                  local  \
# 25   /entradas/ignatius-farray-presenta-nuevo-show-...  Beer Station - Sala 1
# 28   /entradas/comedy-nights-monologos-en-beer-stat...  Beer Station - Sala 1
# 30        /entradas/hardcore-patricia-galvan_e4826004/  Beer Station - Sala 1
# 49    /entradas/yo-nunca-show-de-raul-massana_e289258/  Beer Station - Sala 1
# 52   /entradas/pablo-meixe-quien-aguanta-esto_e4884...  Beer Station - Sala 1
# 53   /entradas/la-bromerie-open-special-edition-en-...  Beer Station - Sala 1
# 59   /entradas/chochito-un-monologo-de-carmen-romer...  Beer Station - Sala 1
# 64   /entradas/isabel-rey-diva-de-barrio-un-show-de...  Beer Station - Sala 1
# 73   /entradas/ruben-faura-la-hora-del-psicologo_e4...  Beer Station - Sala 1
# 74        /entradas/luis-alvaro-el-espectaculo_e64297/  Beer Station - Sala 1
# 84   /entradas/jaime-caravaca-y-su-experiencia-comi...  Beer Station - Sala 1
# 94   /entradas/david-rodri-multitask-y-mileurista-e...  Beer Station - Sala 1
# 98   /entradas/comedia-anonima-micro-abierto-de-com...  Beer Station - Sala 1
# 99   /entradas/open-beer-open-mic-de-stand-up-comed...  Beer Station - Sala 1
# 109  /entradas/sparks-el-show-de-humor-negro-silvia...  Beer Station - Sala 1
# 116  /entradas/nene-que-me-jodan-un-monologo-muy-jo...  Beer Station - Sala 1
# 117           /entradas/mamarrachas-open-mic_e4890894/  Beer Station - Sala 1
# 118  /entradas/mierda-fresca-open-stand-up-comedy-p...  Beer Station - Sala 1
# 119    /entradas/ladys-night-en-beer-station_e4856010/  Beer Station - Sala 1
# 127  /entradas/carmen-romero-y-bianca-kovacs-odio-a...  Beer Station - Sala 1
# 140       /entradas/kalderas-stand-up-comedy_e4818553/  Beer Station - Sala 1
# 145  /entradas/jaja-party-presentado-por-javi-duran...  Beer Station - Sala 1
# 209  /entradas/salomon-y-jose-andres-monologos_e488...  Beer Station - Sala 1
# 210         /entradas/javi-duran-intimissimi_e4898650/  Beer Station - Sala 1
# 212           /entradas/regular-angel-codon-_e4899818/  Beer Station - Sala 1
# 215                        /entradas/vaquero_e4856564/  Beer Station - Sala 1
# 229  /entradas/pringer-a-los-que-das-a-la-izquierda...  Beer Station - Sala 1
# 233   /entradas/quique-matilla-vastante-vien_e4883705/  Beer Station - Sala 1
#
#                                            nombre_show  n_opiniones
# 25   Ignatius Farray presenta nuevo show STAND-UP C...          571
# 28            Comedy Nights, monólogos en Beer Station          837
# 30                          Hardcore - Patricia Galván          163
# 49                     YO NUNCA SHOW,  de Raúl Massana          157
# 52                  Pablo Meixe - ¿Quién aguanta esto?           27
# 53   La Bromerie Open Special Edition, en Beer Station           53
# 59              Chochito, un monólogo de Carmen Romero           17
# 64     Isabel Rey - Diva de barrio, un show de comedia           51
# 73                 Rubén Faura - La hora del psicólogo          288
# 74                        Luis Álvaro - El espectáculo          203
# 84   Jaime Caravaca y Su Experiencia Cómica Definitiva           24
# 94   David Rodri - Multitask y mileurista, en Beer ...           52
# 98          Comedia Anónima (micro abierto de comedia)         1010
# 99             Open Beer - Open Mic de stand-up comedy          136
# 109     Sparks- El show de humor negro - Silvia Sparks           64
# 116      Nene, ¡Que me jodan! , un monólogo muy jodido           38
# 117                               Mamarrachas Open Mic           17
# 118  Mierda Fresca Open - Stand-Up Comedy presentad...           52
# 119                        Ladys Night en Beer Station           94
# 127  Carmen Romero y Bianca Kovacs - Odio a la gent...           25
# 140                         Kalderas - Stand Up Comedy           66
# 145             Jaja Party - Presentado por Javi Durán           13
# 209                  Salomón y Jose Andrés - Monólogos            6
# 210                           Javi Durán - Intimissimi            6
# 212                              Regular - Ángel Codón           -1
# 215                                            Vaquero            7
# 229              Pringer: a los que das a la izquierda            1
# 233                     Quique Matilla - Vastante vien            3

# %%
# Calcular el número de páginas (son 10 comentarios por página)
df_beer['num_paginas'] = (df_beer['n_opiniones'] // 10) + 1
# Cambio los'-1' por 0
df_beer['n_opiniones'] = df_beer['n_opiniones'].replace(-1, 0)

# Ver el DataFrame actualizado
df_beer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 13
#      10     # Verificar si comienza con '10'
#      11     if n_opiniones.startswith('10'):
#      12         # Quitar '10' del inicio
# ---> 13         df_beer.at[index, 'n_opiniones'] = int(n_opiniones[2:])
#      15 # Ver el DataFrame actualizado
#      16 df_beer
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # Guardamos el filtro del Beer Station

# %%
# Especifico la ruta y el nombre del archivo CSV
ruta_archivo_csv = '../01_data/filtro_beer.csv'

# Guardo el DataFrame en un archivo CSV
df_beer.to_csv(ruta_archivo_csv, index=False)

# %%
# Función para extraer comentarios de una página específica
def extraer_comentarios(url, nombre_show, nombre_local):
    """
    Esta función extrae comentarios de una página web y devuelve una lista de diccionarios con información detallada sobre cada comentario.
    
    Requiere las siguientes bibliotecas:
    - requests
    - BeautifulSoup (bs4)
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    comentarios = soup.select(".rws-results-review-item")
    lista_comentarios = []

    for comentario in comentarios:
        nota_total = comentario.select_one(".aui-ratingBadge--large").text
        fecha = comentario.select_one(".meta-info__date").text
        grupo_de = comentario.select_one(".meta-info__company .aui-badge-text").text

        aspectos = comentario.select(".rws-circle-chart-list__item")

        if aspectos:
            calidad = aspectos[0].select_one(".rws-circle-chart__value-container span").text
            puesta_en_escena = aspectos[1].select_one(".rws-circle-chart__value-container span").text
            interpretacion = aspectos[2].select_one(".rws-circle-chart__value-container span").text

            comentario_dict = {
                "fecha": fecha,
                "nota_total": nota_total,
                "grupo_de": grupo_de,
                "calidad_del_espectáculo": calidad,
                "puesta_en_escena": puesta_en_escena,
                "interpretación_artística": interpretacion,
                "nombre_show": nombre_show,  
                "nombre_local": nombre_local  
            }

            lista_comentarios.append(comentario_dict)

    return lista_comentarios

def convertir_fecha(fecha):
    meses = {
        "enero": "January",
        "febrero": "February",
        "marzo": "March",
        "abril": "April",
        "mayo": "May",
        "junio": "June",
        "julio": "July",
        "agosto": "August",
        "septiembre": "September",
        "octubre": "October",
        "noviembre": "November",
        "diciembre": "December"
    }
    partes = fecha.split()
    partes[1] = meses[unidecode(partes[1].lower())]
    fecha_nueva = " ".join(partes)
    return pd.to_datetime(fecha_nueva, format='%d %B %Y', errors='coerce')

# %% [markdown]
# # Iniciamos extracción

# %%
# URL base de la página
base_url = "https://www.atrapalo.com"

# Inicializar lista para almacenar todos los comentarios
todos_los_comentarios = []

# Iterar a través de las filas de df_filtrado
for index, row in df_beer.iterrows():
    url = f"{base_url}{row['url']}"
    nombre_show = row['nombre_show']
    nombre_local = row['local']
    num_paginas = row['num_paginas']
    
    # Iterar a través de las páginas
    for i in range(1, num_paginas + 1):
        url_pagina = f"{url}page-{i}/"
        comentarios_pagina = extraer_comentarios(url_pagina, nombre_show, nombre_local)
        todos_los_comentarios.extend(comentarios_pagina)
    
    # Pasar a DataFrame los datos
    df_comentarios = pd.DataFrame(todos_los_comentarios)

    # Aplicar la función a la columna 'fecha'
    df_comentarios['fecha'] = df_comentarios['fecha'].apply(convertir_fecha)

    # Quitar 'sobre 10' de las columnas de calidad del espectáculo, puesta en escena e interpretación artística
    df_comentarios['calidad_del_espectáculo'] = df_comentarios['calidad_del_espectáculo'].str.replace(r'\s+sobre\s+10', '', regex=True)
    df_comentarios['puesta_en_escena'] = df_comentarios['puesta_en_escena'].str.replace(r'\s+sobre\s+10', '', regex=True)
    df_comentarios['interpretación_artística'] = df_comentarios['interpretación_artística'].str.replace(r'\s+sobre\s+10', '', regex=True)

    # Guardar el DataFrame en un archivo CSV
    df_comentarios.to_csv(f"../01_data/comentarios_{nombre_show}.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 32
#      29 df_comentarios['interpretación_artística'] = df_comentarios['interpretación_artística'].str.replace(r'\s+sobre\s+10', '', regex=True)
#      31 # Guardar el DataFrame en un archivo CSV
# ---> 32 df_comentarios.to_csv(f"../01_data/comentarios_{nombre_show}.csv", index=False)
#
# File ~\anaconda3\envs\proyecto_final\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\anaconda3\envs\proyecto_final\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\proyecto_final\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File ~\anaconda3\envs\proyecto_final\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: '../01_data/comentarios_Pablo Meixe - ¿Quién aguanta esto?.csv'

# %% [markdown]
# Se ha parado debido a que en el nombre del show había caracteres especiales, seguimos en el siguiente cuaderno
